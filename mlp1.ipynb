# %%
pip install numpy

# %%
pip install pandas matplotlib seaborn scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error , r2_score

# %%
train=pd.read_csv("https://storage.googleapis.com/kagglesdsdata/competitions/5407/868283/train.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1749533855&Signature=byzjead8Qd%2B3ym%2BWg2itOYDXDZjN9Li8LQQdj4bZOpBaTOZaq152tSgGsHMLwwbJgbQxu7saMAofv%2F01aIOs4u2jZ0f49VeL9bVxYlKEc1aJhkYzUDmrwbBocjEYFqIYtJoMYrxiPjgXp8V6PH1%2FvPGs8zTQC0xGcwlXOGyuUqS4G2RNPxljG37%2BVQ6Tqwz6mIyfr%2BqBTfIM1NbhiglNOIW4s7kNc8DVjHUzx8SnPlyZ24RlvN0SAlRc2k5uw2Wdb1sTKd8xaxwm%2FnAUgAGE1NLPki7r%2Bde5xJJy82GD8220%2FAJE8OK1zf7wkGaYrEFGVdpO1WZ%2FoVDMnFiRACPhqw%3D%3D&response-content-disposition=attachment%3B+filename%3Dtrain.csv")
df.head()
test=pd.read_csv("https://storage.googleapis.com/kagglesdsdata/competitions/5407/868283/test.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1749534444&Signature=A6i9QrrckZNGNYBrm46RCinlxDcgqJWhBUrE1Y9mOg4oW5VNYKxdgXzqsl8Hj5oOG8qmLuhwV%2FobSmG9338gpdRaFsvwHaZIcUml5%2BSwmda8H%2FbWminZ%2BeX9lvPfLOW7gQ18NSJRP4%2BmxCTg%2BwcHpm60pSqcCLbNxe3ARkF0KrIBtfyqawJ2c3qxWLEoboXXqDV258BTYoLzC8uz4i9517R0e6mnuUuP8v674MxikLiV%2F19lKF3JmvdcVCKMOP7h%2BkjlPJHQmesClknO5I36Fd77wR53gKsTAuLcRKYFEDGY7xuWm4GjZnVCBKklMtbOvQ1O4xp40J9AAbGuqqKBUA%3D%3D&response-content-disposition=attachment%3B+filename%3Dtest.csv")

# %%
data=["GrLivArea","BedroomAbvGr","FullBath"].copy()

# %%
x_train=train[data].copy()
y_train=train["SalePrice"]
x_test=test[data].copy()

# %%
x_train.dropna(inplace=True)
y_train=y_train[x_train.index]
x_test.fillna(x_test.mean(),inplace=True)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction=model.predict(x_test)

# %%
submission=pd.DataFrame({"ID":test["Id"],"SalePrice":prediction})

# %%
print(submission.head())
# Out:
#      ID      SalePrice
# 0  1461  120100.812977
# 1  1462  139898.208279
# 2  1463  202611.414586
# 3  1464  199859.871426
# 4  1465  192059.204300
